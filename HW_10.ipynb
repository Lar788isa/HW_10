# %% [markdown]
# ## Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера.
# Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
rating_csv = pd.read_csv('ratings.csv')
rating_csv.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
rating_csv = rating_csv.query('rating == 5')
rating_csv.head()
# Out:
#    userId  movieId  rating  timestamp
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 6       1      101     5.0  964980868
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
rating_csv['movieId'].value_counts().sort_values(ascending=False).head()
# Out:
# 318     153
# 296     123
# 356     116
# 2571    109
# 260     104
# Name: movieId, dtype: int64

# %%
movie_max = movie_csv.query('movieId == 318')
movie_max
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# ## Второй способ решения

# %%
movie_csv = pd.read_csv('movies.csv')
movie_csv.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
# сгруппировала в один файл по movieId
joined = rating_csv.merge(movie_csv, on= 'movieId', how= 'left')

# %%
# отсортировала по оценке 5
joined_5 = joined.query('rating == 5')

# %%
# отсортировала по названию фильма и подсчитала по строчно по группировке каждого фильма, отсортировала по убыванию.
joined_5['title'].value_counts().sort_values(ascending=False).head()
# Out:
# Shawshank Redemption, The (1994)             153
# Pulp Fiction (1994)                          123
# Forrest Gump (1994)                          116
# Matrix, The (1999)                           109
# Star Wars: Episode IV - A New Hope (1977)    104
# Name: title, dtype: int64

# %% [markdown]
# ## Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония)
# категорий 4, 12 и 21 за период с 2005 по 2010 года.
# Не учитывайте в расчетах отрицательные значения quantity.

# %%
power_coun = pd.read_csv('power.csv')
power_coun.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
power_coun = power_coun[(power_coun['country'] == 'Lithuania') | (power_coun['country'] == 'Latvia')| (power_coun['country'] == 'Estonia')  ]
power_coun = power_coun[power_coun['category'].isin([4,12,21])]
power_coun = power_coun.query('2004 < year < 2011')
power_coun = power_coun.query(' quantity > 0')
sum(power_coun['quantity'])
# Out:
# 240580.0

# %% [markdown]
# ## Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
pd.read_html('https://www.finanz.ru/valyuty/v-realnom-vremeni', encoding='utf-8')[1]
# Out:
#     Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
# 0          NaN            GBP/RUB       844726      -               827276
# 1          NaN            EUR/RUB       709724      -               698230
# 2          NaN            USD/RUB       639737      -               632136
# 3          NaN            JPY/RUB        05905      -                05803
# 4          NaN            CNY/RUB        92227      -                91129
# 5          NaN            CHF/RUB       664192      -               652023
# 6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
# 7          NaN            EUR/USD        11097      -                11036
# 8          NaN            EUR/GBP        08402      -                08431
# 9          NaN            EUR/JPY      1202500      -              1202250
# 10         NaN            EUR/CHF        10689      -                10699
# ...

# %%
# к сожалению в таком виде я так и не разобралась.  где найти 'class': 'line-content'?!? 
# И в инете не смогла найти информацию совсем для нулевых. Посоветуйте где можно почитать?!

df = pd.read_html('https://www.finanz.ru/valyuty/v-realnom-vremeni', attrs = {'class': 'line-content'},encoding='utf-8' )
